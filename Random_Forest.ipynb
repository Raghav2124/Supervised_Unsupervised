# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification

# %%
x,y=make_classification(n_features=5,n_redundant=0,n_informative=5,n_clusters_per_class=1)

# %%
data=pd.DataFrame(x,columns=["col1","col2","col3","col4","col5"])
data["target"]=y
print(data.shape)
# Out:
# (100, 6)

# %%
data.head()
# Out:
#        col1      col2      col3      col4      col5  target
# 0 -2.420717 -2.130414 -0.960691  1.066671  0.365176       0
# 1 -0.997818 -0.265034 -1.630664  1.651407  3.120641       0
# 2 -0.721549  0.750614  0.126036  2.919176  2.395734       0
# 3  1.852942  3.623260  1.316101  1.280656  1.568445       0
# 4  1.752256 -0.531427 -1.427844  1.936518 -0.737723       1

# %%
def sample_rows(data,percent):
    return data.sample(int(percent*data.shape[0]),replace=True)

# %%
def sample_features(data,percent):
    cols=random.sample(data.columns.tolist()[:-1],int(percent*(data.shape[1]-1)))
    return data[cols]

# %%
def combined_sampling(data,row_percent,col_percent):
    new_d=sample_rows(data,row_percent)
    return sample_features(new_d,col_percent)

# %%
df1=sample_rows(data,0.1)

# %%
df2=sample_rows(data,0.1)

# %%
df3=sample_rows(data,0.1)

# %%
from sklearn.tree import DecisionTreeRegressor
clf1=DecisionTreeRegressor()

clf2=DecisionTreeRegressor()
clf3=DecisionTreeRegressor()

# %%
clf1.fit(df1.iloc[:,0:5],df1.iloc[:,-1])
clf2.fit(df2.iloc[:,0:5],df2.iloc[:,-1])
clf3.fit(df3.iloc[:,0:5],df3.iloc[:,-1])
# Out:
# DecisionTreeRegressor()

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(clf1)
# Out:
# [Text(0.6, 0.8333333333333334, 'x[0] <= -0.055\nsquared_error = 0.24\nsamples = 10\nvalue = 0.6'),
#  Text(0.4, 0.5, 'x[3] <= 1.619\nsquared_error = 0.16\nsamples = 5\nvalue = 0.2'),
#  Text(0.2, 0.16666666666666666, 'squared_error = 0.0\nsamples = 4\nvalue = 0.0'),
#  Text(0.6, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.8, 0.5, 'squared_error = 0.0\nsamples = 5\nvalue = 1.0')]

# %%
plot_tree(clf2)
# Out:
# [Text(0.5, 0.75, 'x[0] <= -0.377\nsquared_error = 0.24\nsamples = 10\nvalue = 0.6'),
#  Text(0.25, 0.25, 'squared_error = 0.0\nsamples = 4\nvalue = 0.0'),
#  Text(0.75, 0.25, 'squared_error = 0.0\nsamples = 6\nvalue = 1.0')]

# %%
plot_tree(clf3)
# Out:
# [Text(0.5, 0.75, 'x[0] <= 1.019\nsquared_error = 0.09\nsamples = 10\nvalue = 0.1'),
#  Text(0.25, 0.25, 'squared_error = 0.0\nsamples = 9\nvalue = 0.0'),
#  Text(0.75, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0')]

# %%
clf1.predict(np.array([0.551380,-1.876815,-1.807618,-1.557932,-0.039809]).reshape(1,5))
# Out:
# C:\Users\raghav.aggarwal\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([1.])

# %%
clf2.predict(np.array([0.551380,-1.876815,-1.807618,-1.557932,-0.039809]).reshape(1,5))
# Out:
# C:\Users\raghav.aggarwal\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([1.])

# %%
clf3.predict(np.array([0.551380,-1.876815,-1.807618,-1.557932,-0.039809]).reshape(1,5))
# Out:
# C:\Users\raghav.aggarwal\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([0.])
